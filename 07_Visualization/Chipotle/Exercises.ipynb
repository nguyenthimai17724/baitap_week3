# %% [markdown]
# # Visualizing Chipotle's Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# set this so the graphs open internally
# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/chipotle.tsv).

# %%
url = 'https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/chipotle.tsv'
chipo = pd.read_csv(url, sep='\t')

print(chipo.head())
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
url = 'https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/chipotle.tsv'
chipo = pd.read_csv(url, sep='\t')

print(chipo.head())
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
print(chipo.head(10))
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. Create a histogram of the top 5 items bought

# %%
top_items = chipo['item_name'].value_counts().head(5)

plt.figure(figsize=(10,6))
top_items.plot(kind='bar', color='skyblue')
plt.title('Top 5 Items Bought')
plt.xlabel('Item Name')
plt.ylabel('Quantity Purchased')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Step 6. Create a scatterplot with the number of items orderered per order price
# #### Hint: Price should be in the X-axis and Items ordered in the Y-axis

# %%
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x.replace('$', '')))

order_counts = chipo.groupby('order_id')['quantity'].sum()

order_prices = chipo.groupby('order_id')['item_price'].sum()

plt.figure(figsize=(10,6))
plt.scatter(order_prices, order_counts, alpha=0.5, color='skyblue')
plt.title('Number of Items Ordered vs. Order Price')
plt.xlabel('Order Price')
plt.ylabel('Number of Items Ordered')
plt.show()

# %% [markdown]
# ### Step 7. BONUS: Create a question and a graph to answer your own question.

# %%
order_counts = chipo.groupby('order_id')['quantity'].sum() 
order_prices = chipo.groupby('order_id')['item_price'].sum() 

plt.figure(figsize=(10,6))
plt.scatter(order_counts, order_prices, alpha=0.5, color='green')
plt.title('Relationship Between Number of Items Ordered and Order Price')
plt.xlabel('Number of Items Ordered')
plt.ylabel('Order Price ($)')
plt.show()
